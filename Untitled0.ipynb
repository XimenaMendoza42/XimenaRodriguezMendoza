# %%
print ("...Operadores Matematicos...")
print ("...Operacion de Suma 5 + 8 =" , 5 + 8)
print ("...Operacion de Resta 9 - 7 =" , 9 - 7)
print ("...Operacion de Multiplicacion 5 * 8 =" , 5 * 8)

print ("...Operacion de Suma 7 + 3 =" , 7 + 3)
print ("...Operacion de Suma 8 + 5 =" , 8 + 5)
print ("...Operacion de Suma 6 + 6 =" , 6 + 6)
print ("...Operacion de Suma 5 + 7 =" , 5 + 7)
print ("...Operacion de Suma 3 + 8 =" , 3 + 8)

print ("...Operacion de Resta 8 - 5 =" , 8 - 5)
print ("...Operacion de Resta 10 - 4 =" , 10 - 4)
print ("...Operacion de Resta 9 - 3 =" , 9 - 3)
print ("...Operacion de Resta 6 - 2 =" , 6 - 2)
print ("...Operacion de Resta 4 - 1 =" , 4 - 1)

print ("...Operacion de Multiplicacion 5 * 4" , 5 * 4)
print ("...Operacion de multiplicacion 7 * 3 =" , 7 + 3)
print ("...Operacion de multiplicacion 8 * 5 =" , 8 + 5)
print ("...Operacion de multiplicacion  6 * 6 =" , 6 + 6)
print ("...Operacion de multiplicacion  5 + 7 =" , 5 * 7)


print ("...Operacion de division 8 - 5 =" , 8 / 5)
print ("...Operacion de division10 - 4 =" , 10 / 4)
print ("...Operacion de division 9 - 3 =" , 9 / 3)
print ("...Operacion de division 6 - 2 =" , 6 / 2)
print ("...Operacion de division  4 - 1 =" , 4 / 1)


...Operadores Matematicos...
...Operacion de Suma 5 + 8 = 13
...Operacion de Resta 9 - 7 = 7
...Operacion de Multiplicacion 5 * 8 = 48

# %%
n1=int(input("Ingrese numero1: "))
n2=int(input("Ingrese numero2: "))
r=n1+n2
print(n1, "+", n2, "=", r)

n1=int(input("Ingrese numero1: "))
n2=int(input("Ingrese numero2: "))
r=n1+n2
print(n1, "+", n2, "=", r)

n1=int(input("Ingrese numero1: "))
n2=int(input("Ingrese numero2: "))
r=n1+n2
print(n1, "+", n2, "=", r)

n1=int(input("Ingrese numero1: "))
n2=int(input("Ingrese numero2: "))
r=n1+n2
print(n1, "+", n2, "=", r)

n1=int(input("Ingrese numero1: "))
n2=int(input("Ingrese numero2: "))
r=n1+n2
print(n1, "+", n2, "=", r)

n1=int(input("Ingrese numero1: "))
n2=int(input("Ingrese numero2: "))
r=n1+n2
print(n1, "+", n2, "=", r)

n1=int(input("Ingrese numero1: "))
n2=int(input("Ingrese numero2: "))
r=n1+n2
print(n1, "+", n2, "=", r)

n1=int(input("Ingrese numero1: "))
n2=int(input("Ingrese numero2: "))
r=n1+n2
print(n1, "+", n2, "=", r)

n1=int(input("Ingrese numero1: "))
n2=int(input("Ingrese numero2: "))
r=n1+n2
print(n1, "+", n2, "=", r)

n1=int(input("Ingrese numero1: "))
n2=int(input("Ingrese numero2: "))
r=n1+n2
print(n1, "+", n2, "=", r)

# %%
n1=int(input("Ingrese numero1: "))
n2=int(input("Ingrese numero2: "))
r=n1/n2
print(n1, "/", n2, "=", r)

n1=int(input("Ingrese numero1: "))
n2=int(input("Ingrese numero2: "))
r=n1/n2
print(n1, "/", n2, "=", r)

n1=int(input("Ingrese numero1: "))
n2=int(input("Ingrese numero2: "))
r=n1/n2
print(n1, "/", n2, "=", r)

n1=int(input("Ingrese numero1: "))
n2=int(input("Ingrese numero2: "))
r=n1/n2
print(n1, "/", n2, "=", r)

n1=int(input("Ingrese numero1: "))
n2=int(input("Ingrese numero2: "))
r=n1/n2
print(n1, "/", n2, "=", r)

n1=int(input("Ingrese numero1: "))
n2=int(input("Ingrese numero2: "))
r=n1/n2
print(n1, "/", n2, "=", r)

n1=int(input("Ingrese numero1: "))
n2=int(input("Ingrese numero2: "))
r=n1/n2
print(n1, "/", n2, "=", r)

n1=int(input("Ingrese numero1: "))
n2=int(input("Ingrese numero2: "))
r=n1/n2
print(n1, "/", n2, "=", r)

n1=int(input("Ingrese numero1: "))
n2=int(input("Ingrese numero2: "))
r=n1/n2
print(n1, "/", n2, "=", r)

n1=int(input("Ingrese numero1: "))
n2=int(input("Ingrese numero2: "))
r=n1/n2
print(n1, "/", n2, "=", r)

# %%
n1=int(input("Ingrese numero1: "))
n2=int(input("Ingrese numero2: "))
r=n1*n2
print(n1, "*", n2, "=", r)

n1=int(input("Ingrese numero1: "))
n2=int(input("Ingrese numero2: "))
r=n1*n2
print(n1, "*", n2, "=", r)

n1=int(input("Ingrese numero1: "))
n2=int(input("Ingrese numero2: "))
r=n1*n2
print(n1, "*", n2, "=", r)

n1=int(input("Ingrese numero1: "))
n2=int(input("Ingrese numero2: "))
r=n1*n2
print(n1, "*", n2, "=", r)

n1=int(input("Ingrese numero1: "))
n2=int(input("Ingrese numero2: "))
r=n1*n2
print(n1, "*", n2, "=", r)

n1=int(input("Ingrese numero1: "))
n2=int(input("Ingrese numero2: "))
r=n1*n2
print(n1, "*", n2, "=", r)

n1=int(input("Ingrese numero1: "))
n2=int(input("Ingrese numero2: "))
r=n1*n2
print(n1, "*", n2, "=", r)

n1=int(input("Ingrese numero1: "))
n2=int(input("Ingrese numero2: "))
r=n1*n2
print(n1, "*", n2, "=", r)

n1=int(input("Ingrese numero1: "))
n2=int(input("Ingrese numero2: "))
r=n1*n2
print(n1, "*", n2, "=", r)

n1=int(input("Ingrese numero1: "))
n2=int(input("Ingrese numero2: "))
r=n1*n2
print(n1, "*", n2, "=", r)

# %%
n1=int(input("Ingrese numero1: "))
n2=int(input("Ingrese numero2: "))
r=n1-n2
print(n1, "-", n2, "=", r)

n1=int(input("Ingrese numero1: "))
n2=int(input("Ingrese numero2: "))
r=n1-n2
print(n1, "-", n2, "=", r)

n1=int(input("Ingrese numero1: "))
n2=int(input("Ingrese numero2: "))
r=n1-n2
print(n1, "-", n2, "=", r)

n1=int(input("Ingrese numero1: "))
n2=int(input("Ingrese numero2: "))
r=n1-n2
print(n1, "-", n2, "=", r)

n1=int(input("Ingrese numero1: "))
n2=int(input("Ingrese numero2: "))
r=n1-n2
print(n1, "-", n2, "=", r)

n1=int(input("Ingrese numero1: "))
n2=int(input("Ingrese numero2: "))
r=n1-n2
print(n1, "-", n2, "=", r)

n1=int(input("Ingrese numero1: "))
n2=int(input("Ingrese numero2: "))
r=n1-n2
print(n1, "-", n2, "=", r

      n1=int(input("Ingrese numero1: "))
n2=int(input("Ingrese numero2: "))
r=n1-n2
print(n1, "-", n2, "=", r

      n1=int(input("Ingrese numero1: "))
n2=int(input("Ingrese numero2: "))
r=n1-n2
print(n1, "-", n2, "=", r

      n1=int(input("Ingrese numero1: "))
n2=int(input("Ingrese numero2: "))
r=n1-n2
print(n1, "-", n2, "=", r

# %%
b= 0
a= 0

if type (b) is not int:
  raise Exception("Error de Tipo - Unicamente se permiten enteros")

  elif b == 0:
       print("No se puede dividir entre el cero")

  else:
      print(a/b)
      print(a/b)

# %%
a= float(input("Valor de a:"))
b= float(input("Valor de b:"))
x = -b/a
print("Respuesta: ", x)
# Out:
# Valor de a:4
# Valor de b:8
# Respuesta:  -2.0

# %%
a= float(input("Valor de a:"))
b= float(input("Valor de b:"))
if a !=0:
  x = -b/a
print("Respuesta: ", x)

if a == 0:
   if b !=0:
    print("La operación no se puede realizar")
   if b == 0:
    print("La operación puede tener varias opciones")
# Out:
# Valor de a:10
# Valor de b:8
# Respuesta:  -0.8

# %%
a = 50
b = 52
if a < b:
  print(a,"Es menor que", b)
    elif a > b:
  print(a,"Es mayor que", b)
    else:
  print(a,"Es igual que", b)
# Out:
#   File "<tokenize>", line 5
#     elif a > b:
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
for i in (4,15):
  if i % 2 == 0:
    print (f"{i} es par")
  else:
    print(f"{i} es impar")
# Out:
# 4 es par
# 15 es impar

# %%
secreto = 9
intento = 0

while intento != secreto:
   intento = int(input("Adivina el número: "))
   if intento < seceto:
     print("Muy Bajo")
   elif intento > secreto:
    print("Muy Alto")

print("!Corecto¡")
